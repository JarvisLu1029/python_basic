# %% [markdown]
# 百貨公司周年慶 消費金額超過 2000 要折 200
#
# 請撰寫一支程式
# 計算客戶消費的結帳金額

# %%
total = 2500
discount = 200

if total >= 2000:
    # total = total - discount
    total -= discount

print(total)
# Out:
# 2300

# %% [markdown]
# 滿2000折200, 滿4000折400, 滿6000折600.......

# %%
# 相除取整數
total = 9000
discount = 200

if total >= 2000:
    # total = total*0.9 # 錯誤的寫法
    n = total // 2000 # 相除取整數
    total -= discount * n # 折幾次 200

print(total)
# Out:
# 8200
