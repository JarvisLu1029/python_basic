# %% [markdown]
# |基本型態| int | float | boolean | string |
# |:---:|:---:|:---:|:---:|:---:|
# |創建方式|`num = 10`|`float_num = 2.5`| `parse_ok = True` | |

# %% [markdown]
# |容器型態| list | tuple | set | dict |
# |:---:|:---:|:---:|:---:|:---:|
# |創建方式| | `num_tuple = (1, 2, 3)` | | `info_dict = {'name': 'Jarvis', 'age': 18}` |

# %% [markdown]
# 整數 (int)、浮點數 (float)

# %%
num = 10
float_num = 2.5
print(num)
print(float_num)
# Out:
# 10
# 2.5

# %% [markdown]
# 布林值 (boolean)

# %%
parse_ok = True
print(parse_ok)
parse_not_ok = False
print(parse_not_ok)
print(type(parse_ok))
# Out:
# True
# False
# <class 'bool'>

# %% [markdown]
# 字串 (string)

# %%
my_name = 'Jarvis'
print(my_name)

x = 'True'
print(x)
# type() 檢查資料型態
print(type(x))
# Out:
# Jarvis
# True
# <class 'str'>

# %% [markdown]
# 列表 (list)

# %%
num_list = [1, 2, 3]
print(num_list)
print(type(num_list))
# Out:
# [1, 2, 3]
# <class 'list'>

# %% [markdown]
# 元組 (tuple)

# %%
num_tuple = (1, 2, 3)
print(num_tuple)
print(type(num_tuple))
# Out:
# (1, 2, 3)
# <class 'tuple'>

# %% [markdown]
# 集合 (set)

# %%
num_set = {1, 2, 3}
print(num_set)
print(type(num_set))
# Out:
# {1, 2, 3}
# <class 'set'>

# %% [markdown]
# 字典 (dict)

# %%
info_dict = {'name': 'Jarvis', 'age': 18}
print(info_dict)
print(type(info_dict))
# Out:
# {'name': 'Jarvis', 'age': 18}
# <class 'dict'>
