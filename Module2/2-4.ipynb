# %% [markdown]
# | 求偶數 | 求奇數 |
# |:---|:---|
# | | |

# %% [markdown]
# 算術運算子

# %%
# print(9+4)
num = 9 + 4
print(num)

print(2**3)

print(250%2)

print(100//9)
# Out:
# 13
# 8
# 0
# 11

# %% [markdown]
# 賦值運算子

# %%
a, b = 3, 5
print(a, b)
# b = b + a
b += a
print(b)
# Out:
# 3 5
# 8

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %%
num = 11
print(num == 11)
print(num == 10)

if num == 10:
    print('num = 10')

# 返回縮排 Shift + Tab
print(num)

if num > 5:
    print('num 大於 5')
# Out:
# True
# False
# 11
# num 大於 5

# %% [markdown]
# 邏輯運算子 and / or / not

# %%
age = 18
name = 'Bill'

if age > 10 and name == 'Bill' and age == 20 and age == 18:
    print('and OK')

if age < 10 or name == 'Bill' or age == 18:
    print('or OK')

if not age < 10:
    print('not OK')
# Out:
# or OK
# not OK

# %% [markdown]
# 成員運算子 in / not in

# %%
age = 18
age_list = [16, 18, 20, 22]

if age in age_list:
    print('age in the list')

if 50 not in age_list:
    print('50 not in the list')
# Out:
# age in the list
# 50 not in the list

# %% [markdown]
# 身分運算子 is / is not

# %%
x = 345
y = 345
# id() 查詢記憶體位址
print(id(x))
print(id(y))

if x is y: # 要判斷值一不一樣 不能用 is
    print('x and y are the same.')
# Out:
# 2177041959568
# 2177041959984
# x and y are the same.

# %%
x = True

# True, False, None
if x is True:
    print('x is True')
# Out:
# x is True

# %%
x = 123
y = 234

print(id(x))
print(id(y))
if x is not y:
    print('x and y not same.')
# Out:
# 140707225217272
# 140707225220824
# x and y not same.

# %% [markdown]
# 位元運算子

# %%
x = 1 # 0001
y = 3 # 0011

print(x&y) # 0001
print(x|y) # 0011
print(x^y) # 0010
# Out:
# 1
# 3
# 2
