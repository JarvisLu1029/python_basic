# %% [markdown]
# | | |
# |:---|:---|
# | | |

# %% [markdown]
# 算術運算子

# %% [markdown]
# 賦值運算子

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %% [markdown]
# 邏輯運算子 and / or / not

# %% [markdown]
# 成員運算子 in / not in

# %% [markdown]
# 身分運算子 is / is not

# %% [markdown]
# 位元運算子
