# %% [markdown]
# 條件語句 if-elif-else

# %%
'''
條件判斷
if ...
if ... else ...
if ... elif ... else ...

'''

# %% [markdown]
# ##### if

# %% [markdown]
# ##### if...else...

# %% [markdown]
# ##### if...elif... (else)
