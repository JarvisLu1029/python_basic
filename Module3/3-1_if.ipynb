# %% [markdown]
# 條件語句 if-elif-else

# %%
'''
條件判斷
if ...
if ... else ...
if ... elif ... else ...

'''

# %% [markdown]
# ##### if

# %%
num = 10

if num > 5:
    print('num > 5')

print(num)
# Out:
# num > 5
# 10

# %% [markdown]
# ##### if...else...

# %%
fruit = 'apple'
fruit = 'banana'

if fruit == 'banana':
    print('banana')
else:
    print('apple')
# Out:
# banana

# %% [markdown]
# ##### if...elif... (else)

# %%
name = 'Jarvis'

if name == 'Alex':
    print('name: Alex')
elif name == 'James':
    print('name: James')
elif name == 'Bill':
    print('name: Bill')
else:
    print('Not Found')


if 'J' in name:
    print('J in name.')
# Out:
# Not Found
# J in name.
