# %%
# f-string (又稱作 formatted string literals, version >= 3.6)
name = "Jarvis"
age = 18

print(f"name: {name}, age: {age}")
# Out:
# name: Jarvis, age: 18

# %%
# 靠左對齊、靠右對齊
result = f"name: [{name:<10}], age: [{age:>10}]"
print(result)
# Out:
# name: [Jarvis    ], age: [        18]

# %%
# 靠左對齊、靠右對齊，字數不足，補「X」
# (沒寫補什麼，預設空格)
result = f"name: [{name:X<10}], age: [{age:>10}]"
print(result)
# Out:
# name: [JarvisXXXX], age: [        18]

# %%
# 置中對齊
result = f"name: [{name:^10}], age: [{age:^4}]"
print(result)
# Out:
# name: [  Jarvis  ], age: [ 18 ]

# %%
# 指定文字長度上限 (只有文字，才在格式化字串中加入「.」來限定字串長度)
result = f"name: [{name:<10.3}], age: [{age:>10}]"
print(result)
# Out:
# name: [Jar       ], age: [        18]

# %%
# 小數點幾位
f_num = 1233.746567
result = f"{f_num:.0f}"

print(f"{f_num:.2f}")
print(result)
print(f"經過 f-string 的: {type(result)}")
# Out:
# 1233.75
# 1234
# 經過 f-string 的: <class 'str'>

# %%
f_num = 3.8
print(int(f_num)) # 整數去小數點 -> int
print(f"{f_num:.0f}") # 四捨五入 -> 字串
# Out:
# 3
# 4

# %%
num = round(3.74256)
print(num)
# Out:
# 4

# %%
# \ 用法
