# %% [markdown]
# |string方法| `str.replace(<old_str>, <new_str>)` |  |  |  |
# |:---:|:---:|:---:|:---:|:---:|
# |功能| 替換字串 | | | |

# %%
# 字串變數初始化
num_str = "1, 2, 3, 4"

print(num_str)
# Out:
# 1, 2, 3, 4

# %%
# 替換字串
'''
string.replace(str1, str2)
將 string 中的 str1 替換成 str2
'''
name = "Alex"
name = name.replace("ex", "len")

print(name)
# Out:
# Allen

# %%
string01 = "1   1ccccc1   1"
string01 = string01.replace(' ', '')
print(string01)
# Out:
# 11ccccc11

# %%
string01 = "ccold&hotd"
print(string01[-1])

string01 = string01[1:-1]
print(string01)
# Out:
# d
# cold&hot

# %%
# 去除兩側空格
'''
string.strip() 只能移除開頭和結尾
去除字串 string 左、右兩邊的空格
'''
string01 = "1   1ccccc1   1"
string01 = string01.strip('1')
string01 = string01.strip()
print(string01)
# Out:
# 1ccccc1

# %%
# 字串小寫變大寫
'''
string.lower()
將字串 string 裡的字母全部改成小寫
'''
print("CAR".lower())

'''
string.upper()
將字串 string 裡的字母全部改成大寫
'''
print("car".upper())
# Out:
# car
# CAR

# %%
greeting = "Hello!World!Hello!John"
str_list = greeting.split('!')

print(str_list)
# Out:
# ['Hello', 'World', 'Hello', 'John']
