# %%
# tuple 初始化: 第一種
num_tuple = (1, 2, 3, 4)
print(num_tuple)
# Out:
# (1, 2, 3, 4)

# %%
# tuple 初始化: 第二種
num_tuple2 = 1, 2, 3, 4
print(num_tuple2)
print(type(num_tuple2))
# Out:
# (1, 2, 3, 4)
# <class 'tuple'>

# %%
a, b = 1, 2
c = 3, 4

print(a)
print(b)
print(c)
# Out:
# 1
# 2
# (3, 4)

# %%
# 透過指定索引輸出值
num_tuple = (1, 2, 3, 4)
print(num_tuple[0])
print(num_tuple[3])
# Out:
# 1
# 4

# %%
# 複數變數修改值
a, b = 10, 20
a, b = b, a

print(a)
print(b)
# Out:
# 20
# 10

# %%
# tuple 不可以修改指定索引的值
num_tuple3 = (1, 2, 3, 4, 5)
num_tuple3[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # tuple 不可以修改指定索引的值
#       2 num_tuple3 = (1, 2, 3, 4, 5)
# ----> 3 num_tuple3[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
# (list)可以修改指定索引的值
num_list = list(num_tuple3)
print(f"強制轉型: {num_list}")

num_list[0] = 10
print(num_list)

num_tuple4 = tuple(num_list)
print(num_tuple4)
# Out:
# 強制轉型: [1, 2, 3, 4, 5]
# [10, 2, 3, 4, 5]
# (10, 2, 3, 4, 5)

# %%
# 用 for 迴圈逐一輸出資料
for num in num_tuple4:
    print(num)
# Out:
# 10
# 2
# 3
# 4
# 5

# %%
# 用 len 計算 tuple 資料個數
print(len(num_tuple4))
# Out:
# 5
